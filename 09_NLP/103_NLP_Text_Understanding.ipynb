# %% [markdown]
# # Natural Language Understanding
#
# In this section we go through topics related to text understanding. We cover such topics like:
#
# - Similarity measures
# - Word Vectors
# - Vector Space Model
# - Type of vectorizers
# - Build a vectorizer with Tensorflow.

# %% [markdown]
# ## Similarity measures
#
# Word does have different meanings. This makes the comparison and analysis a bit more complex.

# %%
from textblob import Word

w = Word("developer")

for synset, definition in zip(w.get_synsets(), w.define()):
    print(synset, definition)
# Out:
# Synset('developer.n.01') someone who develops real estate (especially someone who prepares a site for residential or commercial use)
# Synset('developer.n.02') photographic equipment consisting of a chemical solution for developing film

# %% [markdown]
# ## Similarity measures
#
# There are plenty of methods to measure the similarity of strings. Two most popular Python libraries examples for such measure are shown. We compare two strings: trains and training. The SequenceMatcher class allow us to use the Gestalt pattern matching algorithm:

# %%
from difflib import SequenceMatcher
a = "training"
b = "trains"
print(len(a))
print(len(b))
ratio = SequenceMatcher(None, a, b).ratio()
print(ratio)
# Out:
# 8
# 6
# 0.7142857142857143

# %% [markdown]
# The distance is a normalized value between 0 and 1, where 1 means identical.
#
# A different approach is shown below. We use the Jellyfish library. There are a few methods that we can use here. One of it is the Levenshtein distance. Below the distance and normalize distance values are calculated.

# %%
import jellyfish
distance = jellyfish.levenshtein_distance(a,b)
print(distance)

normalized_distance = distance/max(len(a),len(b))
print(1.0-normalized_distance)
# Out:
# 3
# 0.625

# %% [markdown]
# Some words can be more similar to each other than other. We can build a similarity matrix to check it where 1 mean equal and 0 totally different.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

tokens = nlp(u'king queen horse cat desk lamp')

for first_token in tokens:
    for second_token in tokens:
        print(first_token.text, second_token.text, first_token.similarity(second_token))
# Out:
# king king 1.0
# king queen 0.27960336
# king horse 0.49118555
# king cat 0.25511637
# king desk 0.36102036
# king lamp 0.26506075
# queen king 0.27960336
# queen queen 1.0
# queen horse 0.536151
# queen cat 0.493864
# queen desk 0.30205265
# queen lamp 0.16359532
# horse king 0.49118555
# horse queen 0.536151
# horse horse 1.0
# horse cat 0.64121884
# horse desk 0.5525366
# horse lamp 0.2729874
# cat king 0.25511637
# cat queen 0.493864
# cat horse 0.64121884
# cat cat 1.0
# cat desk 0.6911984
# cat lamp 0.29131043
# desk king 0.36102036
# desk queen 0.30205265
# desk horse 0.5525366
# desk cat 0.6911984
# desk desk 1.0
# desk lamp 0.46721974
# lamp king 0.26506075
# lamp queen 0.16359532
# lamp horse 0.2729874
# lamp cat 0.29131043
# lamp desk 0.46721974
# lamp lamp 1.0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Token.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   if __name__ == '__main__':

# %% [markdown]
# We can also compare sentences:

# %%
doc1 = nlp(u"Warsaw is the largest city in Poland.")
doc2 = nlp(u"Crossaint is baked in France.")
doc3 = nlp(u"An emu is a large bird.")

for doc in [doc1, doc2, doc3]:
    for other_doc in [doc1, doc2, doc3]:
        print(doc.similarity(other_doc))
# Out:
# 1.0
# 0.6784152883332049
# 0.594525942849461
# 0.6784152883332049
# 1.0
# 0.38468479474207784
# 0.594525942849461
# 0.38468479474207784
# 1.0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   import sys

# %% [markdown]
# The similarity matrix looks like following:
#
# |       | doc1 | doc2 | doc3 |
# |-------|------|------|------|
# | **doc1** | 1.0  | 0.72 | 0.65 |
# | **doc 2** | 0.72 | 1.0  | 0.40 |
# | **doc 3** | 0.65 | 0.40 | 1.0  |

# %% [markdown]
# ## Word Vectors
#
# SpaCy does have already a set of words that are vectorized.
#
# Let's take a look at the vectors that are available in spaCy using the previous example:

# %%
nlp = spacy.load("en_core_web_sm")

tokens = nlp(u'king queen horse cat desk lamp')

for token in tokens:
    print(str(token)+" "+str(token.vector))
# Out:
# king [ 0.7403561   0.77890664  0.643012   -0.3156419  -0.37801027  0.24781099
#  -0.27596375 -0.48104045 -1.0922432   0.7472374  -0.8444613   0.251671
#   0.3781827   1.0818894   0.19885059  1.1837918   0.32404995 -0.41512138
#   0.22909242 -0.6617618  -0.6469198   0.21754637 -1.4141312  -0.44726843
#  -0.65253    -0.1971674   1.4106697   0.4257809   0.5523951   0.9876823
#   0.23307711 -1.685848   -0.2306067  -1.602057    0.53701496 -0.6796323
#  -0.30905232  0.58602345  0.18551111  1.1123197  -0.13620321 -1.2072787
#   0.12539807  2.4069881  -1.7813005  -0.5720622  -0.9088881   1.0045041
#   1.4330277   0.5898565   0.6349354   0.19462962 -0.1415244   0.92118454
#   0.03492123  0.24171326 -0.58086985  0.4785628   0.12072126 -0.39131016
#  -0.36981663 -0.78168213 -0.21472251 -0.15595332  0.09013814 -0.6507518
#   0.18933167  0.7546793   1.147484   -0.57860124  0.89020646 -0.7004458
#   0.3455518  -1.0024034  -0.54194725  0.5664586  -1.1234642   0.37864003
#  -0.7667741   1.0651305  -0.56816816  0.784024   -0.21306357  0.13464579
#   0.63092375 -0.4130606  -0.0318578   0.2062679  -1.3126504  -0.25829643
#  -1.0168767   0.5092703  -0.6110325   0.05518585  0.24992216 -1.3489935 ]
# queen [ 0.0425881   0.8766949  -0.9280895  -0.15460783 -0.6788025  -0.65131474
#  -0.8265821  -0.22646283 -0.42759934  0.21870333 -0.45833692  0.98471904
#  -0.793265   -0.73211217 -0.22174501  1.7801414  -0.5077679   1.5546699
#  -0.35028893  0.2262795   0.03278545  0.45649374 -0.82688934 -0.00323246
#   0.05064965  0.09970683  0.9203265  -0.7179134  -0.4539331   0.9000578
#   0.02582479  0.9340404   0.9500698   0.3377635   0.80855477 -0.2554049
#   0.57489085 -0.00526136  0.30307278  1.2029392   0.13210236 -0.3491311
#  -0.33958513  0.4355222  -0.9337795  -1.3824778  -0.4980573  -0.46834958
#   1.0183595  -0.02999926  0.6365727  -0.30892146 -0.4366815  -0.28994983
#   0.34227613  0.5208598  -0.46260774  0.6712682  -0.4231125   0.80904543
#  -0.5000452  -0.31842208  0.7695562  -0.7093441  -0.8635399  -1.0627235
#  -0.38144213 -0.7847942   1.3946874  -0.70955753 -0.07416473 -0.3514941
#   0.45403165 -0.20514624  1.1095313   0.6718399   0.20646839  0.6916711
#  -0.7130916  -1.6240096  -0.47955206  0.4233497  -0.4440773   0.4398712
#   0.52878135 -0.36750317 -0.8242364   0.6258117   0.43301472 -1.032985
# %%
len(doc1.vector)
# Out:
# 96

# %% [markdown]
# A nice example of word vectorization done by some researchers at Warsaw University: [Word2Vec](https://lamyiowce.github.io/word2viz/).

# %% [markdown]
# ## Negative sampling
#
# It is a simpler implementation of word2vec. It is faster as it takes only a few terms in each iteration for training insted of the whole dataset as in previous example. This is why it's called negative sampling.
#
# First of all, we define helper methods that are used later.

# %%
def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def sigmoid(batch, stochastic=False):
    return  1.0 / (1.0 + np.exp(-batch))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

# %% [markdown]
# We need to load the data again.

# %%
import nltk
import numpy as np
import pandas as pd
from collections import namedtuple

nltk.download('all')

from nltk.book import *

texts()
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /home/kprzystalski/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# Three variables are important for the training: ``train_dict``, ``train_tokens`` and ``train_set``. The first one contain all unique words used in the corpus. The second is a list of indices of words in the dictionary that correspond to each word used in the raw text.

# %%
#raw_set = nltk.corpus.treebank_raw.raw()[0:50000].replace('.START',' ').replace("\n","").replace("."," ").replace(","," ")
#tokens = [token for token in nltk.word_tokenize(raw_set) if token.isalpha()]
tokens = text6.tokens
train_dict = pd.Series(tokens).unique().tolist()
train_tokens = np.array([train_dict.index(token) for token in tokens])

# %% [markdown]
# The last variable consist of a list of two numbers. The current word index and the word index that is before the word and after the word. Depending on the window size we use also other words that are in the neighbourhood. In this example the window size is set to 2. It means we take two words before and two words after the given word and build the relation in the training data set.

# %%
train_set = []
for i in range(2,len(tokens)-2):
    train_set.append([train_dict.index(tokens[i]), train_dict.index(tokens[i-1])])
    train_set.append([train_dict.index(tokens[i]), train_dict.index(tokens[i-2])])
    train_set.append([train_dict.index(tokens[i]), train_dict.index(tokens[i+1])])
    train_set.append([train_dict.index(tokens[i]), train_dict.index(tokens[i+2])])

train_set = np.random.permutation(np.array(train_set))

# %% [markdown]
# The next step is to set the training configuration. We set the the negative samples size to 10 and the vector size to 100. Learning rate and rate decay are set to 0.1 and 0.995. The training loops are set to 8000000. Logs are displayed each 10000 epoches.

# %%
Config = namedtuple("Config", ["dict_size", "vect_size", "neg_samples", "updates", "learning_rate",
                               "learning_rate_decay", "decay_period", "log_period"])
conf = Config(
    dict_size=len(train_dict),
    vect_size=100,
    neg_samples=10,
    updates=8000000,
    learning_rate=0.1,
    learning_rate_decay=0.995,
    decay_period=10000,
    log_period=10000)

# %% [markdown]
# We loop over ``updates`` and get the word and context from the train set. We calculate the negative context and calculate the word, context and negative sample vectors. The negative context is chosen randomly. In the next step we calcualte the cost and corresponding to it gradients.

# %%
def neg_sample(conf, train_set, train_tokens):
    Vp = randn(conf.dict_size, conf.vect_size)
    Vo = randn(conf.dict_size, conf.vect_size)

    J = 0.0
    learning_rate = conf.learning_rate
    for i in range(conf.updates):
        idx = i % len(train_set)

        word = train_set[idx, 0]
        context = train_set[idx, 1]

        neg_context = np.random.randint(0, len(train_tokens), conf.neg_samples)
        neg_context = train_tokens[neg_context]

        word_vect = Vp[word, :]  # word vector
        context_vect = Vo[context, :];  # context wector
        negative_vects = Vo[neg_context, :]  # sampled negative vectors

        # Cost and gradient calculation starts here
        score_pos = word_vect @ context_vect.T
        score_neg = word_vect @ negative_vects.T

        J -= np.log(sigmoid(score_pos)) + np.sum(np.log(sigmoid(-score_neg)))
        if (i + 1) % conf.log_period == 0:
            print('Update {0}\tcost: {1:>2.2f}'.format(i + 1, J / conf.log_period))
            final_cost = J / conf.log_period
            J = 0.0

        pos_g = 1.0 - sigmoid(score_pos)
        neg_g = sigmoid(score_neg)

        word_grad = -pos_g * context_vect + np.sum(as_matrix(neg_g) * negative_vects, axis=0)
        context_grad = -pos_g * word_vect
        neg_context_grad = as_matrix(neg_g) * as_matrix(word_vect).T

        Vp[word, :] -= learning_rate * word_grad
        Vo[context, :] -= learning_rate * context_grad
        Vo[neg_context, :] -= learning_rate * neg_context_grad

        if i % conf.decay_period == 0:
            learning_rate = learning_rate * conf.learning_rate_decay

    return Vp, Vo, final_cost

# %% [markdown]
# Next do the training:

# %%
Vp, Vo, J = neg_sample(conf, train_set, train_tokens)
# Out:
# Update 10000	cost: 18.63
# Update 20000	cost: 10.73
# Update 30000	cost: 8.35
# Update 40000	cost: 7.41
# Update 50000	cost: 6.61
# Update 60000	cost: 6.15
# Update 70000	cost: 5.69
# Update 80000	cost: 4.87
# Update 90000	cost: 4.59
# Update 100000	cost: 4.43
# Update 110000	cost: 4.38
# Update 120000	cost: 4.27
# Update 130000	cost: 4.14
# Update 140000	cost: 3.96
# Update 150000	cost: 3.82
# Update 160000	cost: 3.74
# Update 170000	cost: 3.71
# Update 180000	cost: 3.68
# Update 190000	cost: 3.58
# Update 200000	cost: 3.54
# Update 210000	cost: 3.50
# Update 220000	cost: 3.44
# Update 230000	cost: 3.35
# Update 240000	cost: 3.33
# Update 250000	cost: 3.32
# Update 260000	cost: 3.28
# Update 270000	cost: 3.25
# Update 280000	cost: 3.19
# Update 290000	cost: 3.18
# Update 300000	cost: 3.14
# Update 310000	cost: 3.11
# Update 320000	cost: 3.12
# Update 330000	cost: 3.07
# Update 340000	cost: 3.02
# Update 350000	cost: 3.02
# Update 360000	cost: 2.99
# Update 370000	cost: 2.96
# Update 380000	cost: 2.96
# Update 390000	cost: 2.92
# Update 400000	cost: 2.90
# Update 410000	cost: 2.87
# Update 420000	cost: 2.88
# Update 430000	cost: 2.88
# Update 440000	cost: 2.84
# Update 450000	cost: 2.85
# Update 460000	cost: 2.82
# Update 470000	cost: 2.81
# Update 480000	cost: 2.78
# Update 490000	cost: 2.77
# Update 500000	cost: 2.79
# Update 510000	cost: 2.74
# Update 520000	cost: 2.76
# Update 530000	cost: 2.71
# Update 540000	cost: 2.71
# Update 550000	cost: 2.67
# Update 560000	cost: 2.72
# Update 570000	cost: 2.69
# Update 580000	cost: 2.67
# Update 590000	cost: 2.65
# Update 600000	cost: 2.66
# Update 7400000	cost: 1.91
# Update 7410000	cost: 1.94
# Update 7420000	cost: 1.95
# Update 7430000	cost: 1.93
# Update 7440000	cost: 1.92
# Update 7450000	cost: 1.92
# Update 7460000	cost: 1.92
# Update 7470000	cost: 1.90
# Update 7480000	cost: 1.93
# Update 7490000	cost: 1.95
# Update 7500000	cost: 1.92
# Update 7510000	cost: 1.92
# Update 7520000	cost: 1.91
# Update 7530000	cost: 1.90
# Update 7540000	cost: 1.91
# Update 7550000	cost: 1.94
# Update 7560000	cost: 1.94
# Update 7570000	cost: 1.93
# Update 7580000	cost: 1.93
# Update 7590000	cost: 1.90
# Update 7600000	cost: 1.90
# Update 7610000	cost: 1.94
# Update 7620000	cost: 1.94
# Update 7630000	cost: 1.93
# Update 7640000	cost: 1.92
# Update 7650000	cost: 1.93
# Update 7660000	cost: 1.92
# Update 7670000	cost: 1.90
# Update 7680000	cost: 1.93
# Update 7690000	cost: 1.94
# Update 7700000	cost: 1.93
# Update 7710000	cost: 1.92
# Update 7720000	cost: 1.92
# Update 7730000	cost: 1.90
# Update 7740000	cost: 1.90
# Update 7750000	cost: 1.93
# Update 7760000	cost: 1.95
# Update 7770000	cost: 1.94
# Update 7780000	cost: 1.92
# Update 7790000	cost: 1.91
# Update 7800000	cost: 1.91
# Update 7810000	cost: 1.90
# Update 7820000	cost: 1.93
# Update 7830000	cost: 1.94
# Update 7840000	cost: 1.93
# Update 7850000	cost: 1.92
# Update 7860000	cost: 1.92
# Update 7870000	cost: 1.90
# Update 7880000	cost: 1.92
# Update 7890000	cost: 1.93
# Update 7900000	cost: 1.94
# Update 7910000	cost: 1.93
# Update 7920000	cost: 1.93
# Update 7930000	cost: 1.89
# Update 7940000	cost: 1.90
# Update 7950000	cost: 1.93
# Update 7960000	cost: 1.93
# Update 7970000	cost: 1.92
# Update 7980000	cost: 1.92
# Update 7990000	cost: 1.93
# Update 8000000	cost: 1.90

# %% [markdown]
# The ``similar_words`` can be used to find related words of the ``word``.

# %%
def lookup_word_idx(word, word_dict):
    try:
        return np.argwhere(np.array(word_dict) == word)[0][0]
    except:
        raise Exception("No such word in dict: {}".format(word))

def similar_words(embeddings, word, word_dict, hits):
    word_idx = lookup_word_idx(word, word_dict)
    similarity_scores = embeddings @ embeddings[word_idx]
    similar_word_idxs = np.argsort(-similarity_scores)    
    return [word_dict[i] for i in similar_word_idxs[:hits]]

# %%
print('\n\nTraining cost: {0:>2.2f}\n\n'.format(J))

sample_words = ['knight', 'holy', 'grail']

Vp_norm = Vp / as_matrix(np.linalg.norm(Vp , axis=1))
for w in sample_words:
    similar = similar_words(Vp_norm, w, train_dict, 5)
    print('Words similar to {}: {}'.format(w, ", ".join(similar)))
# Out:
# Training cost: 1.90
#
#
# Words similar to knight: knight, boom, plover, chord, live
# Words similar to holy: holy, rewr, wind, dramatic, forest
# Words similar to grail: grail, legendary, vache, NI, Bad

# %% [markdown]
# #### References
#
# [1] Jeffrey Pennington, Richard Socher, and Christopher D. Manning. 2014. GloVe: Global Vectors for Word Representation.
